# %%
# %%writefile myfile_write15.txt
# This is my first line in the file
# This is my second line in the file
# This is my third line in the file
# Out:
# Overwriting myfile_write15.txt

# %%
os.getcwd()
os.system('ls')
os.chdir('/Users/ayushkumar/Learning/GitHub/Ayush_Personal/Coding/Python/Practice')
# Out:
# DirectoryTest
# Python_Practice.py
# Python_temp.py
# \
# file_append.txt
# myfile.txt
# myfile_write.txt
# myfile_write15.txt
# myfile_write5.txt
# myfile_x.txt
# myfile_x1.txt
# myfile_x2.txt
# myfile_x5.txt
# myfile_x6.txt

# %%
import os
os.getcwd()
os.chdir('/Users/ayushkumar/Learning/GitHub/Ayush_Personal/Coding/Python/Practice')
os.system("rm  myfile_write15.txt")
# Out:
# 0

# %%
myfile=open('myfile_write15.txt')
myfile1=open('myfile_write115.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 myfile=open('myfile_write15.txt')
# ----> 2 myfile1=open('myfile_write115.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfile_write115.txt'

# %%
myfile=open('myfile_write15.txt')

# %%
pwd
# Out:
# '/Users/ayushkumar/Learning/GitHub/Ayush_Personal/Coding/Python/Practice'

# %%
myfile=open("myfile_write15.txt")
myfile.read()
myfile.close()

# %%
myfile=open("myfile_write15.txt")
myfile.readline()
myfile.readline()
myfile.readline()
# Out:
# 'This is my first line in the file\n'

# %%
with open("myfile_write15.txt","r") as read_append:
    read_append.seek(1)
    print(read_append.read())
# Out:
# hey we are using both mode together
# this is new mode for me
#  file
# This is my third line in the file
# myfile=open('myfile_write15.txt')
# myfile1=open('myfile_write115.txt')
# hey we are using both mode together
# this is new mode for me
# hey we are using both mode together
# this is new mode for me
# hey we are using both mode together
# this is new mode for me
# adding end of the file hey we are using both mode together
# please vaerify with above line this is new mode for me
# adding end of the file hey we are using both mode together
# please vaerify with above line this is new mode for me
# adding end of the file hey we are using both mode together
# please vaerify with above line this is new mode for me
# adding end of the file hey we are using both mode together
# please vaerify with above line this is new mode for me
# adding end of the file hey we are using both mode together
# please vaerify with above line this is new mode for me
# ...

# %%
with open("myfile_write15.txt","r") as read_append:
    read_append.seek(0,2)
    print(read_append.read())
